# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/cars.csv')

# %%
df.head()
# Out:
#    speed  dist
# 0      4     2
# 1      4    10
# 2      7     4
# 3      7    22
# 4      8    16

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_model = LinearRegression()
lin_model.fit(pd.DataFrame(df['speed']), df['dist'])
# Out:
# LinearRegression()

# %%
plt.scatter(df['speed'], df['dist'], color='blue')
plt.plot(df['speed'], lin_model.predict(pd.DataFrame(df['speed'])), color='black')

# %%
lin_model.predict(np.array([40]).reshape(1, -1))
# Out:
# /home/serg/anaconda3/envs/torch/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([139.71725547])
